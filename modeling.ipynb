# %%
import pymongo
import chromadb
from scraping import Reg_API, CommentParser

# %%
client = pymongo.MongoClient()

# %%
client.list_database_names()
# Out:
# ['CSE482_hwk2', 'admin', 'config', 'local']

# %%
db = client.twosix

# %%
comments_coll = db.comments

# %%
api = Reg_API()

# %%
res = api.endpoint("/comments").search("climate").get()

# %%
len(res["data"])
# Out:
# 25

# %%
res
# Out:
# {'data': [{'id': 'PHMSA-2019-0100-2389',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2019-08-06T13:57:16Z',
#     'highlightedContent': 'Comment from <mark><em>Climate</em></mark> Writers',
#     'withdrawn': False,
#     'agencyId': 'PHMSA',
#     'title': 'Comment from Climate Writers',
#     'objectId': '0900006483dd9a06',
#     'postedDate': '2019-08-02T04:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/PHMSA-2019-0100-2389'}},
#   {'id': 'PHMSA-2018-0025-0018',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2019-11-18T20:06:48Z',
#     'highlightedContent': '<mark><em>Climate</em></mark> Writers&hellip;&nbsp;<mark><em>CLIMATE</em></mark> \n\n% lc,070 Co".j~f\' ~~ \nt"\'je~, ().f . 1, 40,_ \n\nOS Dept . ( Tr-~~r~o(~l;o.,..',
#     'withdrawn': False,
#     'agencyId': 'PHMSA',
#     'title': 'Comment of Climate Writers',
#     'objectId': '0900006484164999',
#     'postedDate': '2019-11-18T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/PHMSA-2018-0025-0018'}},
#   {'id': 'FHWA-2021-0022-0044',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-12-15T01:58:34Z',
#     'highlightedContent': '<mark><em>Climate</em></mark> Group  -  Comments&hellip;&nbsp;The <mark><em>Climate</em></mark> Group, Inc. is a U.S. registered 501(c)3 with EIN 43-2073566   \n\n \n\n \n\n \n\n335 Madison Avenue&hellip;&nbsp;The <mark><em>Climate</em></mark> Group would like to share a supportive resource to help guide the deployment of \nelectric&hellip;&nbsp;Yours sincerely \n \nLouisa Plotnick \n \nHead of Program, North America \n<mark><em>Climate</em></mark> Group \n\nmailto:info@theclimategroup.org',
#     'withdrawn': False,
#     'agencyId': 'FHWA',
#     'title': 'Climate Group  -  Comments',
#     'objectId': '0900006484ec8682',
#     'postedDate': '2021-12-14T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/FHWA-2021-0022-0044'}},
#   {'id': 'FWS-R1-ES-2020-0050-1807',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-08-13T14:47:35Z',
#     'highlightedContent': '<mark><em>Climate</em></mark> Writers 08112021',
#     'withdrawn': False,
#     'agencyId': 'FWS',
#     'title': 'Climate Writers 08112021',
#     'objectId': '0900006484c4fe60',
#     'postedDate': '2021-08-13T04:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/FWS-R1-ES-2020-0050-1807'}},
#   {'id': 'FWS-HQ-MB-2018-0090-11675',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2020-07-09T22:05:28Z',
#     'highlightedContent': '<mark><em>CLIMATE</em></mark> WRITERS 07082020&hellip;&nbsp;<mark><em>Climate</em></mark> Writers \n87426 Halderson Road \nEugene, OR 97402 \n\nPublic Comments Processing \nATTN.: FWS-HQ-MB&hellip;&nbsp;Many bird species are in steep decline already due to environmental hazards and \n<mark><em>climate</em></mark> change.',
#     'withdrawn': False,
#     'agencyId': 'FWS',
#     'title': 'CLIMATE WRITERS 07082020',
#     'objectId': '0900006484739a44',
#     'postedDate': '2020-07-09T04:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/FWS-HQ-MB-2018-0090-11675'}},
#   {'id': 'BOEM-2022-0009-0048',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2022-06-07T00:44:18Z',
#     'highlightedContent': '<mark><em>Climate</em></mark> Writers&hellip;&nbsp;<mark><em>CLIMATE</em></mark> WRITERS',
#     'withdrawn': False,
#     'agencyId': 'BOEM',
#     'title': 'Comment from Climate Writers',
#     'objectId': '090000648512fe8a',
#     'postedDate': '2022-06-05T04:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/BOEM-2022-0009-0048'}},
#   {'id': 'FWS-R1-ES-2020-0050-1808',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-08-13T14:48:47Z',
#     'highlightedContent': '<mark><em>Climate</em></mark> Writers-2  08112021',
#     'withdrawn': False,
#     'agencyId': 'FWS',
#     'title': 'Climate Writers-2  08112021',
#     'objectId': '0900006484c4fe62',
#     'postedDate': '2021-08-13T04:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/FWS-R1-ES-2020-0050-1808'}},
#   {'id': 'DOS-2013-0011-0355',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2013-07-11T18:25:34Z',
#     'highlightedContent': 'Alliance for <mark><em>Climate</em></mark> Education&hellip;&nbsp;<mark><em>Climate</em></mark> Education ACE\n\n4/17/2013  Brenda  Vaca Alliance for <mark><em>Climate</em></mark> Education ACE\n\n4/17/2013  Chase&hellip;&nbsp;Bogard Alliance for <mark><em>Climate</em></mark> Education ACE\n\n4/17/2013  chris  reed Alliance for <mark><em>Climate</em></mark> Education ACE&hellip;&nbsp;Alliance for <mark><em>Climate</em></mark> Education ACE\n\n4/17/2013  Gay  Bingham Alliance for <mark><em>Climate</em></mark> Education ACE\n\n4/17&hellip;&nbsp;Bakus Alliance for <mark><em>Climate</em></mark> Education ACE\n\n4/17/2013  Jacob Pabley Alliance for <mark><em>Climate</em></mark> Education ACE&hellip;&nbsp;Alliance for <mark><em>Climate</em></mark> Education ACE\n\n4/17/2013  Jordan   Gilliard Alliance for <mark><em>Climate</em></mark> Education ACE',
#     'withdrawn': False,
#     'agencyId': 'DOS',
#     'title': 'Alliance for Climate Education',
#     'objectId': '0900006481361954',
#     'postedDate': '2013-07-11T04:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/DOS-2013-0011-0355'}},
#   {'id': 'OCC-2020-0042-0455',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2020-12-21T16:49:40Z',
#     'highlightedContent': 'research and observations have led me to the conclusion that unless we stop using fossil fuels and reverse <mark><em>climate</em></mark>&hellip;&nbsp;consensus (IPCC 2018), these farming difficulties are just the beginning of what we can expect as far as <mark><em>climate</em></mark>&hellip;&nbsp;<mark><em>Climate</em></mark> Agroforestry Research\n22 Leonard Street\nGreenfield, MA 01301\n\nReferences:\nIPCC, 2018: Summary&hellip;&nbsp;greenhouse gas emission pathways, in the context of strengthening the global response to the threat of <mark><em>climate</em></mark>&hellip;&nbsp;<mark><em>Climate</em></mark> Agroforestry Research 2&hellip;&nbsp;The maritime <mark><em>climate</em></mark> nourishes a lush landscape.&hellip;&nbsp;<mark><em>Climate</em></mark> Agroforestry Research 3&hellip;&nbsp;<mark><em>Climate</em></mark> Agroforestry Research 1',
#     'withdrawn': False,
#     'agencyId': 'OCC',
#     'title': 'Climate Agroforestry Research',
#     'objectId': '09000064849a94c4',
#     'postedDate': '2020-12-21T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/OCC-2020-0042-0455'}},
#   {'id': 'AMS-LP-24-0012-0117',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2024-06-28T23:27:31Z',
#     'highlightedContent': 'See attached file for comments from Cascade <mark><em>Climate</em></mark>.&hellip;&nbsp;AMS-LP-24-0012_Cascade <mark><em>Climate</em></mark> Response&hellip;&nbsp;Assistance Provider and Third Party Verifier Program\nDocket ID: AMS-LP-24-0012\n\nResponse from Cascade <mark><em>Climate</em></mark>&hellip;&nbsp;June 28, 2024\n\nCascade <mark><em>Climate</em></mark> works to accelerate progress in <mark><em>climate</em></mark> interventions that leverage Earth&hellip;&nbsp;’s\nnatural systems—from soils to oceans to glaciers—to stabilize our <mark><em>climate</em></mark>.&hellip;&nbsp;industry, and policy to overcome the\nbottlenecks that are holding back the most promising open-system <mark><em>climate</em></mark>&hellip;&nbsp;According to the\nIntergovernmental Panel on <mark><em>Climate</em></mark> Change’s Sixth Assessment Report, “the deployment',
#     'withdrawn': False,
#     'agencyId': 'AMS',
#     'title': 'Comment from Cascade Climate',
#     'objectId': '09000064865d1a97',
#     'postedDate': '2024-06-28T04:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/AMS-LP-24-0012-0117'}},
#   {'id': 'DOS-2013-0011-0346',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2013-07-11T18:25:31Z',
#     'highlightedContent': '<mark><em>Climate</em></mark> Parents&hellip;&nbsp;<mark><em>Climate</em></mark> Parents PARENTS\n\n4/17/2013 Robert Russell <mark><em>Climate</em></mark> Parents PARENTS\n\n4/17/2013 Ronda <mark><em>Climate</em></mark> Parents&hellip;&nbsp;Wiesen <mark><em>Climate</em></mark> Parents PARENTS\n\n4/18/2013 Benai <mark><em>Climate</em></mark> Parents PARENTS\n\n4/18/2013 Betsy Rose <mark><em>Climate</em></mark>&hellip;&nbsp;Russell <mark><em>Climate</em></mark> Parents PARENTS\n\n4/18/2013 Joe Phares <mark><em>Climate</em></mark> Parents PARENTS\n\n4/18/2013 Joel <mark><em>Climate</em></mark>&hellip;&nbsp;<mark><em>Climate</em></mark> Parents PARENTS\n\n4/18/2013 Kyle Mcadam <mark><em>Climate</em></mark> Parents PARENTS\n\n4/18/2013 Larry Soll <mark><em>Climate</em></mark>&hellip;&nbsp;<mark><em>Climate</em></mark> Parents PARENTS\n\n4/18/2013 Tamsen Binggeli <mark><em>Climate</em></mark> Parents PARENTS\n\n4/18/2013 Tim Felegy <mark><em>Climate</em></mark>',
#     'withdrawn': False,
#     'agencyId': 'DOS',
#     'title': 'Climate Parents Letters Received April 17-18',
#     'objectId': '0900006481361976',
#     'postedDate': '2013-07-11T04:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/DOS-2013-0011-0346'}},
#   {'id': 'NHTSA-2009-0059-0086',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2009-11-27T17:36:27Z',
#     'highlightedContent': 'National <mark><em>Climate</em></mark> Coalition - Comment&hellip;&nbsp;Gas Emission Standards and \n\nCorporate Average Fuel Economy Standards”\n\nSubmitted by:  The National <mark><em>Climate</em></mark>&hellip;&nbsp;Executive Summary\n\nThe National <mark><em>Climate</em></mark> Coalition (“NCC”) submits these comments to EPA’s “Proposed&hellip;&nbsp;Rather, Congress \nshould craft national <mark><em>climate</em></mark> legislation that balances multiple additional national&hellip;&nbsp;For a variety of reasons, the existing Clean Air Act is a poor mechanism for addressing \n<mark><em>climate</em></mark> change&hellip;&nbsp;Comprehensive <mark><em>climate</em></mark> \nchange and energy legislation has been passed by the U.S.',
#     'withdrawn': False,
#     'agencyId': 'NHTSA',
#     'title': 'National Climate Coalition - Comment',
#     'objectId': '0900006480a5ec6b',
#     'postedDate': '2009-11-27T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/NHTSA-2009-0059-0086'}},
#   {'id': 'PHMSA-2019-0100-1148',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2019-07-30T14:37:23Z',
#     'highlightedContent': "<mark><em>Climate</em></mark> Writers&hellip;&nbsp;Comment from <mark><em>Climate</em></mark> Writers&hellip;&nbsp;<mark><em>CLIMATE</em></mark> \tWRITERS \n\n3 60 7 cc uicur kadAt- DEPARTMENT 'OF \n7RANSPORTAThr EcAl21? )  OR 017.4og.",
#     'withdrawn': False,
#     'agencyId': 'PHMSA',
#     'title': 'Comment from Climate Writers',
#     'objectId': '0900006483d94e8f',
#     'postedDate': '2019-07-16T04:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/PHMSA-2019-0100-1148'}},
#   {'id': 'PHMSA-2019-0100-1131',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2019-07-15T14:14:48Z',
#     'highlightedContent': 'Comment from <mark><em>Climate</em></mark> Writers',
#     'withdrawn': False,
#     'agencyId': 'PHMSA',
#     'title': 'Comment from Climate Writers',
#     'objectId': '0900006483d88e95',
#     'postedDate': '2019-07-12T04:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/PHMSA-2019-0100-1131'}},
#   {'id': 'BOEM-2022-0031-6297',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2022-11-16T01:33:42Z',
#     'highlightedContent': 'Comment from <mark><em>Climate</em></mark> Writers',
#     'withdrawn': False,
#     'agencyId': 'BOEM',
#     'title': 'Comment from Climate Writers',
#     'objectId': '09000064854af79c',
#     'postedDate': '2022-11-14T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/BOEM-2022-0031-6297'}},
#   {'id': 'BOEM-2011-0023-0054',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2013-08-29T18:06:36Z',
#     'highlightedContent': 'Chesapeake <mark><em>Climate</em></mark> Action Network',
#     'withdrawn': False,
#     'agencyId': 'BOEM',
#     'title': 'Chesapeake Climate Action Network',
#     'objectId': '0900006480fc0b68',
#     'postedDate': '2012-02-24T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/BOEM-2011-0023-0054'}},
#   {'id': 'ONRR-2012-0004-0073',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2015-03-16T15:41:43Z',
#     'highlightedContent': '<mark><em>Climate</em></mark> Crisis Working Group',
#     'withdrawn': False,
#     'agencyId': 'ONRR',
#     'title': 'Climate Crisis Working Group',
#     'objectId': '0900006481a46fba',
#     'postedDate': '2015-03-16T04:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/ONRR-2012-0004-0073'}},
#   {'id': 'DOT-OST-2023-0092-0068',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2023-08-11T20:13:59Z',
#     'highlightedContent': '<mark><em>Climate</em></mark> Mayors Response to DOT APRA-I RFI&hellip;&nbsp;Comment from <mark><em>Climate</em></mark> Mayors&hellip;&nbsp;As an organization\nthat represents a bipartisan network of over 350 Mayors committed to <mark><em>climate</em></mark> action&hellip;&nbsp;<mark><em>Climate</em></mark> Mayors’ appreciate the\nAdministration’s efforts to integrate <mark><em>climate</em></mark> and resilience into ARPA-I&hellip;&nbsp;tools for identifying <mark><em>climate</em></mark> impacts, incentivizing the adoption of modern building\ncodes, pathways&hellip;&nbsp;Report to Congressional Committees: <mark><em>CLIMATE</em></mark> CHANGE:\nState and Local Efforts to Reduce Greenhouse Gas&hellip;&nbsp;catalyze investments in <mark><em>climate</em></mark> resilient infrastructure projects across the country.',
#     'withdrawn': False,
#     'agencyId': 'DOT',
#     'title': 'Comment from Climate Mayors',
#     'objectId': '0900006485e1ff98',
#     'postedDate': '2023-08-11T04:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/DOT-OST-2023-0092-0068'}},
#   {'id': 'CEQ-2022-0005-0379',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2023-06-12T20:33:46Z',
#     'highlightedContent': '<mark><em>Climate</em></mark> Writers Comment 1',
#     'withdrawn': False,
#     'agencyId': 'CEQ',
#     'title': 'Climate Writers Comment 1',
#     'objectId': '0900006485b077ef',
#     'postedDate': '2023-06-12T04:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/CEQ-2022-0005-0379'}},
#   {'id': 'CEQ-2022-0005-0378',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2023-06-12T20:32:55Z',
#     'highlightedContent': '<mark><em>Climate</em></mark> Writers Comment 2',
#     'withdrawn': False,
#     'agencyId': 'CEQ',
#     'title': 'Climate Writers Comment 2',
#     'objectId': '0900006485b08548',
#     'postedDate': '2023-06-12T04:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/CEQ-2022-0005-0378'}},
#   {'id': 'BOEM-2024-0022-0054',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2024-07-04T00:33:53Z',
#     'highlightedContent': 'Rogue <mark><em>Climate</em></mark> _ORPSN_ 06_28_2024&hellip;&nbsp;Rogue <mark><em>Climate</em></mark> serves and works alongside Southern Oregon and South Coast communities most\n\nimpacted by&hellip;&nbsp;<mark><em>climate</em></mark> change, including low-income, rural, youth, and communities of color, by\n\norganizing for clean&hellip;&nbsp;Rogue <mark><em>Climate</em></mark> is invested in the protection of the Coos Bay estuary and the <mark><em>climate</em></mark> resilience of\n\nSouth&hellip;&nbsp;Ensuring A Just Transition:\nThrough the <mark><em>Climate</em></mark> Justice Alliance, Rogue <mark><em>Climate</em></mark>, alongside UPROSE and&hellip;&nbsp;Rogue <mark><em>Climate</em></mark> looks forward to continued collaboration and\n\nengagement into the future.',
#     'withdrawn': False,
#     'agencyId': 'BOEM',
#     'title': 'Comment from Rogue Climate',
#     'objectId': '09000064865d6342',
#     'postedDate': '2024-07-03T04:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/BOEM-2024-0022-0054'}},
#   {'id': 'CEQ-2019-0003-173061',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2020-05-04T23:16:20Z',
#     'highlightedContent': 'Comment from <mark><em>Climate</em></mark> Writers (8 signatures)_0224_2&hellip;&nbsp;<mark><em>CLIMATE</em></mark> WRITERS \n\nM1.3 64/mil 44 \nco-L 0 ?',
#     'withdrawn': False,
#     'agencyId': 'CEQ',
#     'title': 'Comment from Climate Writers (8 signatures)',
#     'objectId': '09000064844c39e2',
#     'postedDate': '2020-05-04T04:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/CEQ-2019-0003-173061'}},
#   {'id': 'DOS-2013-0011-0367',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2013-07-18T18:35:06Z',
#     'highlightedContent': '<mark><em>Climate</em></mark> Parents&hellip;&nbsp;Parents\n\n4/19/2013 Angela Wyatt PARENTS <mark><em>Climate</em></mark> Parents\n\n4/19/2013 Brad Jaynes PARENTS <mark><em>Climate</em></mark> Parents&hellip;&nbsp;Dana Mains PARENTS <mark><em>Climate</em></mark> Parents\n\n4/19/2013 Daniel Lee PARENTS <mark><em>Climate</em></mark> Parents\n\n4/19/2013 Darleen&hellip;&nbsp;<mark><em>Climate</em></mark> Parents\n\n4/19/2013 Jeanne Miller PARENTS <mark><em>Climate</em></mark> Parents\n\n4/19/2013 Jeff Colman PARENTS <mark><em>Climate</em></mark>&hellip;&nbsp;<mark><em>Climate</em></mark> Parents\n\n4/19/2013 Thomas Green PARENTS <mark><em>Climate</em></mark> Parents\n\n4/19/2013 Valli Sugden PARENTS <mark><em>Climate</em></mark>&hellip;&nbsp;4/21/2013 Michael PARENTS <mark><em>Climate</em></mark> Parents\n\n4/21/2013 Whitney PARENTS <mark><em>Climate</em></mark> Parents',
#     'withdrawn': False,
#     'agencyId': 'DOS',
#     'title': 'Climate Parents Letters Received April 19-21, 2013',
#     'objectId': '090000648136d5a9',
#     'postedDate': '2013-07-18T04:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/DOS-2013-0011-0367'}},
#   {'id': 'IRS-2023-0042-0199',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2023-10-31T16:54:00Z',
#     'highlightedContent': 'On behalf of <mark><em>Climate</em></mark> Jobs Rhode Island, <mark><em>Climate</em></mark> Jobs Illinois, Texas <mark><em>Climate</em></mark> Jobs Project, and <mark><em>Climate</em></mark>&hellip;&nbsp;FROM: <mark><em>Climate</em></mark> Jobs Rhode Island; <mark><em>Climate</em></mark> Jobs Massachusetts; <mark><em>Climate</em></mark> Jobs Illinois; Texas <mark><em>Climate</em></mark> Jobs&hellip;&nbsp;Sincerely, \n \n \nMichael Roles \nPolicy Director \n<mark><em>Climate</em></mark> Jobs Rhode Island \nmike@climatejobsri.org&hellip;&nbsp;Joe Duffy \nExecutive Director \n<mark><em>Climate</em></mark> Jobs Illinois \n \nBo Delp \nExecutive Director \nTexas <mark><em>Climate</em></mark> Jobs&hellip;&nbsp;Project \n \nRyan Murphy \nExecutive Director \n<mark><em>Climate</em></mark> Jobs Massachusetts \n\nmailto:mike@climatejobsri.org',
#     'withdrawn': False,
#     'agencyId': 'IRS',
#     'title': 'Comment from Climate Jobs Rhode Island, Climate Jobs Illinois, Texas Climate Jobs Project, Climate Jobs Massachusetts',
#     'objectId': '0900006486196a59',
#     'postedDate': '2023-10-31T04:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/IRS-2023-0042-0199'}},
#   {'id': 'USDA-2021-0010-0317',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-11-02T12:37:55Z',
#     'highlightedContent': "Please find The <mark><em>Climate</em></mark> Trust's comments attached.&hellip;&nbsp;Docket ID- USDA-2021-0010_The <mark><em>Climate</em></mark> Trust&hellip;&nbsp;Please find The <mark><em>Climate</em></mark> Trust’s comments to Climate-Smart Agriculture and Forestry Partnership \nProgram&hellip;&nbsp;The <mark><em>Climate</em></mark> Trust  \nThe <mark><em>Climate</em></mark> Trust is a non-profit organization with 25 years’ experience in the carbon&hellip;&nbsp;Based in Portland, Oregon, The <mark><em>Climate</em></mark> Trust works with public, private, and tribal partners throughout&hellip;&nbsp;In addition to developing carbon offset projects, The <mark><em>Climate</em></mark> \nTrust is a recognized policy and thought&hellip;&nbsp;The <mark><em>Climate</em></mark> Trust is among the most experienced carbon market practitioners and has contracted seven",
#     'withdrawn': False,
#     'agencyId': 'USDA',
#     'title': 'Comment from The Climate Trust',
#     'objectId': '0900006484e06192',
#     'postedDate': '2021-11-02T04:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/USDA-2021-0010-0317'}}],
#  'meta': {'aggregations': {'agencyId': [{'docCount': 438517, 'value': 'FWS'},
#     {'docCount': 401696, 'value': 'BLM'},
#     {'docCount': 335306, 'value': 'CEQ'},
#     {'docCount': 209959, 'value': 'FS'},
#     {'docCount': 150179, 'value': 'EPA'},
#     {'docCount': 127398, 'value': 'BOEM'},
#     {'docCount': 96607, 'value': 'NOAA'},
#     {'docCount': 49359, 'value': 'FHWA'},
#     {'docCount': 42447, 'value': 'FNS'},
#     {'docCount': 39683, 'value': 'DOI'},
#     {'docCount': 35258, 'value': 'FAR'},
#     {'docCount': 34591, 'value': 'PHMSA'},
#     {'docCount': 32160, 'value': 'IRS'},
#     {'docCount': 24406, 'value': 'NHTSA'},
#     {'docCount': 14715, 'value': 'MARAD'},
#     {'docCount': 13682, 'value': 'MMS'},
#     {'docCount': 8331, 'value': 'USTR'},
#     {'docCount': 8167, 'value': 'EERE'},
#     {'docCount': 6704, 'value': 'AMS'},
#     {'docCount': 5742, 'value': 'ED'},
#     {'docCount': 5345, 'value': 'DOS'},
#     {'docCount': 5117, 'value': 'OSHA'},
#     {'docCount': 3917, 'value': 'EBSA'},
#     {'docCount': 3747, 'value': 'APHIS'},
#     {'docCount': 2592, 'value': 'FDA'},
#     {'docCount': 2552, 'value': 'CMS'},
#     {'docCount': 2265, 'value': 'HHS'},
#     {'docCount': 2174, 'value': 'USDA'},
#     {'docCount': 1711, 'value': 'USCG'},
#     {'docCount': 1514, 'value': 'HUD'},
#     {'docCount': 1297, 'value': 'DOT'},
#     {'docCount': 1294, 'value': 'USCIS'},
#     {'docCount': 1283, 'value': 'FEMA'},
#     {'docCount': 1248, 'value': 'USBC'},
#     {'docCount': 1222, 'value': 'COE'},
#     {'docCount': 1216, 'value': 'NPS'},
#     {'docCount': 1169, 'value': 'FAA'},
#     {'docCount': 1148, 'value': 'NRC'},
#     {'docCount': 1094, 'value': 'FMCSA'},
#     {'docCount': 1021, 'value': 'ICEB'},
#     {'docCount': 949, 'value': 'FTC'},
#     {'docCount': 949, 'value': 'NRCS'},
#     {'docCount': 920, 'value': 'CDC'},
#     {'docCount': 840, 'value': 'BSEE'},
#     {'docCount': 831, 'value': 'GSA'},
#     {'docCount': 802, 'value': 'OMB'},
#     {'docCount': 783, 'value': 'ATF'},
#     {'docCount': 780, 'value': 'OCC'},
#     {'docCount': 710, 'value': 'DOE'},
#     {'docCount': 507, 'value': 'EOIR'},
#     {'docCount': 494, 'value': 'CFPB'},
#     {'docCount': 486, 'value': 'TREAS'},
#     {'docCount': 455, 'value': 'TTB'},
#     {'docCount': 337, 'value': 'FRA'},
#     {'docCount': 313, 'value': 'CPSC'},
#     {'docCount': 289, 'value': 'ACF'},
#     {'docCount': 288, 'value': 'OSM'},
#     {'docCount': 282, 'value': 'FTA'},
#     {'docCount': 270, 'value': 'FSIS'},
#     {'docCount': 266, 'value': 'NTIA'},
#     {'docCount': 246, 'value': 'WHD'},
#     {'docCount': 234, 'value': 'BIS'},
#     {'docCount': 232, 'value': 'ETA'},
#     {'docCount': 229, 'value': 'ITA'},
#     {'docCount': 216, 'value': 'DEA'},
#     {'docCount': 177, 'value': 'DHS'},
#     {'docCount': 148, 'value': 'NLRB'},
#     {'docCount': 146, 'value': 'SBA'},
#     {'docCount': 139, 'value': 'VA'},
#     {'docCount': 136, 'value': 'DOC'},
#     {'docCount': 131, 'value': 'OSTP'},
#     {'docCount': 124, 'value': 'COLC'},
#     {'docCount': 111, 'value': 'NIST'},
#     {'docCount': 107, 'value': 'DOJ'},
#     {'docCount': 102, 'value': 'NCUA'},
#     {'docCount': 102, 'value': 'RBS'},
#     {'docCount': 83, 'value': 'ONRR'},
#     {'docCount': 79, 'value': 'DOD'},
#     {'docCount': 78, 'value': 'BIA'},
#     {'docCount': 76, 'value': 'OFCCP'},
#     {'docCount': 76, 'value': 'TSA'},
#     {'docCount': 69, 'value': 'NIFA'},
#     {'docCount': 69, 'value': 'SSA'},
#     {'docCount': 64, 'value': 'PTO'},
#     {'docCount': 58, 'value': 'FINCEN'},
#     {'docCount': 57, 'value': 'MSHA'},
#     {'docCount': 57, 'value': 'USCBP'},
#     {'docCount': 56, 'value': 'EIB'},
#     {'docCount': 56, 'value': 'FSA'},
#     {'docCount': 54, 'value': 'OPM'},
#     {'docCount': 49, 'value': 'EEOC'},
#     {'docCount': 46, 'value': 'CNCS'},
#     {'docCount': 44, 'value': 'CCC'},
#     {'docCount': 42, 'value': 'DARS'},
#     {'docCount': 37, 'value': 'LMSO'},
#     {'docCount': 34, 'value': 'GIPSA'},
#     {'docCount': 30, 'value': 'FCIC'},
#     {'docCount': 27, 'value': 'FSOC'},
#     {'docCount': 27, 'value': 'PCSCOTUS'},
#     {'docCount': 23, 'value': 'NASA'},
#     {'docCount': 22, 'value': 'ATBCB'},
#     {'docCount': 22, 'value': 'DOL'},
#     {'docCount': 22, 'value': 'RITA'},
#     {'docCount': 22, 'value': 'RUS'},
#     {'docCount': 21, 'value': 'ASC'},
#     {'docCount': 20, 'value': 'ATSDR'},
#     {'docCount': 18, 'value': 'HRSA'},
#     {'docCount': 17, 'value': 'ACL'},
#     {'docCount': 16, 'value': 'CISA'},
#     {'docCount': 16, 'value': 'USC'},
#     {'docCount': 13, 'value': 'BOP'},
#     {'docCount': 12, 'value': 'FRTIB'},
#     {'docCount': 11, 'value': 'ESA'},
#     {'docCount': 10, 'value': 'ATR'},
#     {'docCount': 10, 'value': 'BOR'},
#     {'docCount': 10, 'value': 'CSREES'},
#     {'docCount': 10, 'value': 'HHSIG'},
#     {'docCount': 10, 'value': 'OTS'},
#     {'docCount': 9, 'value': 'BLS'},
#     {'docCount': 9, 'value': 'OJJDP'},
#     {'docCount': 9, 'value': 'RHS'},
#     {'docCount': 7, 'value': 'ARS'},
#     {'docCount': 7, 'value': 'FMC'},
#     {'docCount': 7, 'value': 'NIH'},
#     {'docCount': 7, 'value': 'ONCD'},
#     {'docCount': 6, 'value': 'CDFI'},
#     {'docCount': 6, 'value': 'SAMHSA'},
#     {'docCount': 5, 'value': 'AID'},
#     {'docCount': 5, 'value': 'NARA'},
#     {'docCount': 4, 'value': 'NIGC'},
#     {'docCount': 4, 'value': 'OJP'},
#     {'docCount': 3, 'value': 'CPPBSD'},
#     {'docCount': 3, 'value': 'FFIEC'},
#     {'docCount': 3, 'value': 'NAL'},
#     {'docCount': 3, 'value': 'OFPP'},
#     {'docCount': 3, 'value': 'USMINT'},
#     {'docCount': 2, 'value': 'EDA'},
#     {'docCount': 2, 'value': 'ERS'},
#     {'docCount': 2, 'value': 'FIRSTNET'},
#     {'docCount': 2, 'value': 'FISCAL'},
#     {'docCount': 2, 'value': 'PBGC'},
#     {'docCount': 2, 'value': 'USA'},
#     {'docCount': 2, 'value': 'VETS'},
#     {'docCount': 2, 'value': 'WCPO'},
#     {'docCount': 1, 'value': 'AHRQ'},
#     {'docCount': 1, 'value': 'CSB'},
#     {'docCount': 1, 'value': 'IHS'},
#     {'docCount': 1, 'value': 'NSPC'},
#     {'docCount': 1, 'value': 'NTSB'},
#     {'docCount': 1, 'value': 'PCLOB'},
#     {'docCount': 1, 'value': 'USAF'},
#     {'docCount': 1, 'value': 'USN'}],
#    'postedDate': [{'docCount': 10,
#      'label': 'Today',
#      'fromDate': '2025-02-12 00:00:00',
#      'toDate': '2025-02-12 23:59:59'},
#     {'docCount': 5365,
#      'label': 'Last 3 Days',
#      'fromDate': '2025-02-10 00:00:00',
#      'toDate': '2025-02-12 23:59:59'},
#     {'docCount': 9892,
#      'label': 'Last 7 Days',
#      'fromDate': '2025-02-06 00:00:00',
#      'toDate': '2025-02-12 23:59:59'},
#     {'docCount': 38848,
#      'label': 'Last 15 Days',
#      'fromDate': '2025-01-29 00:00:00',
#      'toDate': '2025-02-12 23:59:59'},
#     {'docCount': 78943,
#      'label': 'Last 30 Days',
#      'fromDate': '2025-01-14 00:00:00',
#      'toDate': '2025-02-12 23:59:59'},
#     {'docCount': 110436,
#      'label': 'Last 90 Days',
#      'fromDate': '2024-11-15 00:00:00',
#      'toDate': '2025-02-12 23:59:59'}]},
#   'filters': {},
#   'hasNextPage': True,
#   'hasPreviousPage': False,
#   'numberOfElements': 25,
#   'pageNumber': 1,
#   'pageSize': 25,
#   'totalElements': 2133661,
#   'totalPages': 20,
#   'firstPage': True,
#   'lastPage': False}}

# %%
res_doc = api.endpoint("/documents").search("climate").
