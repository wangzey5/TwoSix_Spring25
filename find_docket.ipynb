# %%
import pandas as pd

# Load data
df = pd.read_pickle("data/data.pkl")

# Filter out topic -1
df = df[df["topic"] != -1]

# Target topic label from the spike
target_topic_label = "1_epahqoar20110090_2011nnms_02262011_thesenmajor"

# Filter rows for that topic
df_topic = df[df["topic_label"] == target_topic_label]

# Show the most common docket IDs
print(df_topic["docketId"].value_counts().head(5))
# Out:
# docketId
# EPA-HQ-OAR-2011-0089    961
# EPA-HQ-OAR-2011-0090    621
# EPA-HQ-OGC-2010-1045      7
# EPA-HQ-OAR-2021-0317      5
# EPA-HQ-OAR-2018-0794      4
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                     processed_comment  \
# 0   RE Docket EPAR10OAR20190710 Federal Register N...
# 7   Don t turn white , freedom is important. Nobod...
# 8   I found this regulation interesting because of...
# 9   Regarding the proposed regulation of wood burn...
# 10  I heat my shop and house with wood in our rura...
#
#                      commentId               docketId  documentId  \
# 0   EPA-R10-OAR-2019-0710-0076  EPA-R10-OAR-2019-0710         NaN
# 7   EPA-R10-OAR-2020-0361-0094  EPA-R10-OAR-2020-0361         NaN
# 8   EPA-R10-OAR-2020-0361-0095  EPA-R10-OAR-2020-0361         NaN
# 9   EPA-R10-OAR-2020-0361-0096  EPA-R10-OAR-2020-0361         NaN
# 10  EPA-R10-OAR-2020-0361-0097  EPA-R10-OAR-2020-0361         NaN
#
#                   postedDate agency  \
# 0  2020-02-28 05:00:00+00:00    EPA
# 7  2022-10-31 04:00:00+00:00    EPA
# 8  2022-10-31 04:00:00+00:00    EPA
# 9  2022-10-31 04:00:00+00:00    EPA
# 10 2022-11-03 04:00:00+00:00    EPA
#
#                                             embedding  topic  probability  \
# 0   [-0.05332227051258087, 0.04287220537662506, 0....   2052     0.935041
# 7   [0.09506189823150635, 0.15462402999401093, 0.0...   2222     0.511840
# 8   [0.022214524447917938, 0.1080213412642479, 0.1...   2020     1.000000
# 9   [0.006942305248230696, 0.07918140292167664, -0...    577     0.605677
# 10  [0.03336889296770096, 0.04616007208824158, 0.0...    577     0.735845
#
#                                           topic_label
# 0           2052_psd_hydrofluoric_interpretation_ghgs
# 7   2222_clairsvile_ruleprpikeameren_brotzmanconce...
# 8            2020_cheyenne_tribe_reservation_northern
# 9                          577_stoves_wood_stove_heat
# 10                         577_stoves_wood_stove_heat
